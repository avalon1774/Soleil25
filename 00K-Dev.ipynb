# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %load_ext dotenv
# %dotenv

# %%
import pandas as pd
import logging
import glob
import matplotlib.pyplot as plt
from galaxies import read_nxs_file

logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       3 import glob
#       4 import matplotlib.pyplot as plt
# ----> 5 from galaxiesdata import read_nxs_file
#       7 logger = logging.getLogger(__name__)
#       8 logger.setLevel(logging.INFO)
#
# ModuleNotFoundError: No module named 'galaxiesdata'

# %%
def foo():
    data = read_nxs_file('Yb_elastic_0002.nxs')
    for e, image in zip(data['energies'], data['images']):
        plt.title("Energy: {:.2f} keV".format(e))
        plt.imshow(image) #, cmap='hot')
        # plt.colorbar()
        plt.show()


foo()

# %% [markdown]
# # Sample coordinate systems

# %%
import math

# %%
10 * math.cos(60 * math.pi / 180)
# Out:
# 5.000000000000001

# %%
10 * math.sin(60 * math.pi / 180)
# Out:
# 8.660254037844386
